# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import statsmodels.formula.api as smf 
import statsmodels.api as sm
import os
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = pd.read_csv('/home/sarah/public_cs686//GoodBelly/goodBellyData.csv')
dataModified = data.copy()
dataModified['Total_Sale'] = data['Units_Sold'] * data['Average_Retail_Price']

# %%
demoUnits1 = dataModified[dataModified['Demo'] == 1]['Units_Sold']
demo1_3Units1 = dataModified[dataModified['Demo1_3'] == 1]['Units_Sold']
demo4_5Units1 = dataModified[dataModified['Demo4_5'] == 1]['Units_Sold']
repUnits1 = dataModified[dataModified['Sales_Rep'] == 1]['Units_Sold']
capUnits1 = dataModified[dataModified['Endcap'] == 1]['Units_Sold']

demoUnits0 = dataModified[dataModified['Demo'] == 0]['Units_Sold']
demo1_3Units1 = dataModified[dataModified['Demo1_3'] == 0]['Units_Sold']
demo4_5Units1 = dataModified[dataModified['Demo4_5'] == 0]['Units_Sold']
repSUnits0 = dataModified[dataModified['Sales_Rep'] == 0]['Units_Sold']
capSUnits0 = dataModified[dataModified['Endcap'] == 0]['Units_Sold']

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(5, 7)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Sales_Rep", y = "Units_Sold", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Sales_Rep", y = "Units_Sold", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Sales Representatives VS Units Sold\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Sales Representatives",fontsize=12)
ax2.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Sales_Rep", y="Units_Sold", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Sales_Rep", y="Units_Sold", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Sales Representatives VS Units Sold\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo')

ax.set_title("Sale Representatives VS Total Sales\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Total Sales",fontsize=12)
# Out:
# Text(0,0.5,'Total Sales')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Sale Representatives VS Units Sold\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Units_Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units_Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Sale Representatives VS Units Sold\n Scatterplot(color divided by Demo1_3)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Sale Representatives VS Units Sold\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo", y = "Units_Sold", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo", y = "Units_Sold", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo VS Units Sold\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo",fontsize=12)
ax2.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo VS Units Sold\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo VS Units Sold\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo VS Units_Sold\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Demo VS Units Sold\n Scatterplot(color divided by Demo1_3)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Demo VS Units Sold\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Endcap", y = "Units_Sold", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Endcap", y = "Units_Sold", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Endcap VS Units Sold\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Endcap",fontsize=12)
ax2.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Endcap VS Units Sold\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo')

ax.set_title("Endcap VS Units Sold\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Endcap VS Units Sold\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Endcap VS Units Sold\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Endcap VS Units Sold\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo1_3", y = "Units_Sold", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo1_3", y = "Units_Sold", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo1_3 VS Units Sold\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo1_3",fontsize=12)
ax2.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo1_3", y="Units_Sold", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo1_3", y="Units_Sold", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo1_3 VS Units Sold\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo1_3 VS Units Sold\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo1_3 VS Units Sold\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Demo1_3 VS Units Sold\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo4_5", y = "Units_Sold", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo4_5", y = "Units_Sold", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo4_5 VS Units_Sold\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo4_5",fontsize=12)
ax2.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo4_5", y="Units_Sold", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo4_5", y="Units_Sold", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo4_5 VS Units Sold\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo4_5", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo4_5 VS Units Sold\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo4_5", y="Units_Sold", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo4_5 VS Units Sold\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Units Sold",fontsize=12)
# Out:
# Text(0,0.5,'Units Sold')

# %%
#Endcap*Sales_Rep
Cap1Rep1 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 1]
Cap1Rep0 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 0]
Cap0Rep1 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 1]
Cap0Rep0 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 0]

Cap1Rep1Sale = Cap1Rep1['Units_Sold']
Cap1Rep0Sale = Cap1Rep0['Units_Sold']
Cap0Rep1Sale = Cap0Rep1['Units_Sold']
Cap0Rep0Sale = Cap0Rep0['Units_Sold']
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
data_to_plot = [Cap1Rep1Sale, Cap0Rep1Sale, Cap1Rep0Sale, Cap0Rep0Sale]
fig = plt.figure(1, figsize=(11, 7))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, 1, 'gD')
ax.set_xticklabels(['Endcap = 1 & Sales_Rep = 1', 'Endcap = 0 & Sales_Rep = 1', 'Endcap = 1 & Sales_Rep = 0', 'Endcap = 0 & Sales_Rep = 0'])
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# [Text(0,0,'Endcap = 1 & Sales_Rep = 1'),
#  Text(0,0,'Endcap = 0 & Sales_Rep = 1'),
#  Text(0,0,'Endcap = 1 & Sales_Rep = 0'),
#  Text(0,0,'Endcap = 0 & Sales_Rep = 0')]

# %%
#Endcap*Sales_Rep
Cap1Demo1 = dataModified[dataModified['Endcap'] == 1][dataModified['Demo'] == 1]
Cap1Demo0 = dataModified[dataModified['Endcap'] == 1][dataModified['Demo'] == 0]
Cap0Demo1 = dataModified[dataModified['Endcap'] == 0][dataModified['Demo'] == 1]
Cap0Demo0 = dataModified[dataModified['Endcap'] == 0][dataModified['Demo'] == 0]

Cap1Demo1Sale = Cap1Demo1['Units_Sold']
Cap1Demo0Sale = Cap1Demo0['Units_Sold']
Cap0Demo1Sale = Cap0Demo1['Units_Sold']
Cap0Demo0Sale = Cap0DemoDemo0['Units_Sold']

data_to_plot = [Cap1Demo1Sale, Cap0Demo1Sale, Cap1Demo0Sale, Cap0Demo0Sale]
fig = plt.figure(1, figsize=(9, 5))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, 1, 'gD')
ax.set_xticklabels(['Endcap = 1 & Demo = 1', 'Endcap = 0 & Demo = 1', 'Endcap = 1 & Demo = 0', 'Endcap = 0 & Demo = 0'])
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c592d312caca> in <module>()
# ...

# %%
#Endcap*Sales_Rep
Demo1Rep1 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 1]
Demo1Rep0 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 0]
Demo0Rep1 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 1]
Demo0Rep0 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 0]

Demo1Rep1Sale = Demo1Rep1['Units_Sold']
Demo1Rep0Sale = Demo1Rep0['Units_Sold']
Demo0Rep1Sale = Demo0Rep1['Units_Sold']
Demo0Rep0Sale = Demo0Rep0['Units_Sold']

data_to_plot = [Demo1Rep1Sale, Demo1Rep0Sale, Demo0Rep1Sale, Demo0Rep0Sale]
fig = plt.figure(1, figsize=(9, 5))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, 1, 'gD')
ax.set_xticklabels(['Rep = 1 & Demo = 1', 'Rep = 0 & Demo = 1', 'Rep = 1 & Demo = 0', 'Rep = 0 & Demo = 0'])
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /home/sarah/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# ...

# %% [markdown]
# The best model currently I find is 3 and 5. We need to do some test on them.
