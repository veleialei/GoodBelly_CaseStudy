# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import statsmodels.formula.api as smf 
import statsmodels.api as sm
import os
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = pd.read_csv('/home/sarah/public_cs686//GoodBelly/goodBellyData.csv')
dataModified = data.copy()
dataModified['Total_Sale'] = data['Units_Sold'] * data['Average_Retail_Price']

# %%
demoSale1 = dataModified[dataModified['Demo'] == 1]['Total_Sale']
repSale1 = dataModified[dataModified['Sales_Rep'] == 1]['Total_Sale']
capSale1 = dataModified[dataModified['Endcap'] == 1]['Total_Sale']

demoSale0 = dataModified[dataModified['Demo'] == 0]['Total_Sale']
repSale0 = dataModified[dataModified['Sales_Rep'] == 0]['Total_Sale']
capSale0 = dataModified[dataModified['Endcap'] == 0]['Total_Sale']

# %%
demoUnits1 = dataModified[dataModified['Demo'] == 1]['Units_Sold']
demo1_3Units1 = dataModified[dataModified['Demo1_3'] == 1]['Units_Sold']
demo4_5Units1 = dataModified[dataModified['Demo4_5'] == 1]['Units_Sold']
repUnits1 = dataModified[dataModified['Sales_Rep'] == 1]['Units_Sold']
capUnits1 = dataModified[dataModified['Endcap'] == 1]['Units_Sold']

demoUnits0 = dataModified[dataModified['Demo'] == 0]['Units_Sold']
demo1_3Units1 = dataModified[dataModified['Demo1_3'] == 0]['Units_Sold']
demo4_5Units1 = dataModified[dataModified['Demo4_5'] == 0]['Units_Sold']
repSUnits0 = dataModified[dataModified['Sales_Rep'] == 0]['Units_Sold']
capSUnits0 = dataModified[dataModified['Endcap'] == 0]['Units_Sold']

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Sales_Rep", y = "Total_Sale", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Sales_Rep", y = "Total_Sale", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Sale Representatives VS Revenue\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Sales Representatives",fontsize=12)
ax2.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Sale Representatives VS Revenue\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo')

ax.set_title("Sale Representatives VS Revenue\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Sale Representatives VS Revenue\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Sale Representatives VS Revenue\n Scatterplot(color divided by Demo1_3)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Sales_Rep", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Sale Representatives VS Revenue\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Sales Representatives",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo", y = "Total_Sale", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo", y = "Total_Sale", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo VS Revenue\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo",fontsize=12)
ax2.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo VS Revenue\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo VS Revenue\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo VS Revenue\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Demo VS Revenue\n Scatterplot(color divided by Demo1_3)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Demo VS Revenue\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Demo",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Endcap", y = "Total_Sale", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Endcap", y = "Total_Sale", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Endcap VS Revenue\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Endcap",fontsize=12)
ax2.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Endcap VS Revenue\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo')

ax.set_title("Endcap VS Revenue\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Endcap VS Revenue\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo1_3')

ax.set_title("Endcap VS Revenue\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Endcap", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Endcap VS Revenue\n Scatterplot(color divided by Demo)", fontsize=14)
ax.set_xlabel("Endcap",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo1_3", y = "Total_Sale", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo1_3", y = "Total_Sale", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo1_3 VS Revenue\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo1_3",fontsize=12)
ax2.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo1_3", y="Total_Sale", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo1_3", y="Total_Sale", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo1_3 VS Revenue\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo1_3 VS Revenue\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo1_3 VS Revenue\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo1_3", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Demo4_5')

ax.set_title("Demo1_3 VS Revenue\n Scatterplot(color divided by Demo4_5)", fontsize=14)
ax.set_xlabel("Demo1_3",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
sns.set_style("whitegrid")  
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":12,"axes.labelsize":12})
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax2 = plt.subplot()  # 创建作图区域

ax2 = sns.boxplot(x = "Demo4_5", y = "Total_Sale", 
                 data=dataModified, width = 0.72, linewidth=1.5, palette="Set3", notch=True)

ax2 = sns.swarmplot(x="Demo4_5", y = "Total_Sale", 
                  data=dataModified, linewidth=0, color = "grey", alpha=0.4)
ax2.set_title('Demo1_3 VS Revenue\n Boxplot + Swarmplot', fontsize=14)
ax2.set_xlabel("Demo1_3",fontsize=12)
ax2.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)
ax = sns.violinplot(x="Demo4_5", y="Total_Sale", 
                  data=dataModified, linewidth=1, palette="Set3")
ax = sns.stripplot(x="Demo4_5", y="Total_Sale", 
                  data=dataModified, linewidth=0, jitter=True, color = "grey", alpha=0.4)
ax.set_title("Demo4_5 VS Revenue\n Violinplot + Stripplot", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo4_5", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Endcap')

ax.set_title("Demo4_5 VS Revenue\n Scatterplot(color divided by Endcap)", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

ax = sns.swarmplot(x="Demo4_5", y="Total_Sale", 
                  data=dataModified, linewidth=0.5, palette="Set3", hue = 'Sales_Rep')

ax.set_title("Demo4_5 VS Revenue\n Scatterplot(color divided by Sales_Rep)", fontsize=14)
ax.set_xlabel("Demo4_5",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
# Out:
# Text(0,0.5,'Revenue')

# %%
fig = plt.figure()  # 创建画布
fig.set_size_inches(6, 10)

# %%
#Endcap*Sales_Rep
Cap1Rep1 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 1]
Cap1Rep0 = dataModified[dataModified['Endcap'] == 1][dataModified['Sales_Rep'] == 0]
Cap0Rep1 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 1]
Cap0Rep0 = dataModified[dataModified['Endcap'] == 0][dataModified['Sales_Rep'] == 0]

Cap1Rep1Sale = Cap1Rep1['Total_Sale']
Cap1Rep0Sale = Cap1Rep0['Total_Sale']
Cap0Rep1Sale = Cap0Rep1['Total_Sale']
Cap0Rep0Sale = Cap0Rep0['Total_Sale']
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/sarah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
data_to_plot = [Cap1Rep1Sale, Cap0Rep1Sale, Cap1Rep0Sale, Cap0Rep0Sale]
fig = plt.figure(1, figsize=(10, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, 1, 'gD')
ax.set_xticklabels(['Endcap = 1 & Sales_Rep = 1', 'Endcap = 0 & Sales_Rep = 1', 'Endcap = 1 & Sales_Rep = 0', 'Endcap = 0 & Sales_Rep = 0'])
# Out:
# /home/sarah/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# [Text(0,0,'Endcap = 1 & Sales_Rep = 1'),
#  Text(0,0,'Endcap = 0 & Sales_Rep = 1'),
#  Text(0,0,'Endcap = 1 & Sales_Rep = 0'),
#  Text(0,0,'Endcap = 0 & Sales_Rep = 0')]

# %%
goodBellyModel = sm.OLS.from_formula('Total_Sale ~ Demo + Endcap + Sales_Rep + Demo1_3 + Demo4_5', dataModified)
goodBellyResid = goodBellyModel.fit()
print(goodBellyResid.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     520.1
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          2.57e-314
# Time:                        17:59:32   Log-Likelihood:                -9741.7
# No. Observations:                1386   AIC:                         1.950e+04
# Df Residuals:                    1380   BIC:                         1.953e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    708.6014     11.128     63.679      0.000     686.772     730.430
# Demo         470.5338     31.802     14.796      0.000     408.148     532.919
# Endcap      1159.6304     38.605     30.038      0.000    1083.899    1235.362
# Sales_Rep    353.3748     15.559     22.711      0.000     322.852     383.897
# Demo1_3      279.5151     20.922     13.360      0.000     238.474     320.557
# Demo4_5      303.7404     28.074     10.819      0.000     248.668     358.813
# ==============================================================================
# Omnibus:                      169.821   Durbin-Watson:                   1.367
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1223.370
# Skew:                          -0.309   Prob(JB):                    2.23e-266
# Kurtosis:                       7.561   Cond. No.                         6.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel1 = sm.OLS.from_formula('Total_Sale ~ Endcap + Demo + Sales_Rep + Demo1_3 + Demo4_5', dataModified)
goodBellyResid1 = goodBellyModel1.fit()
print(goodBellyResid1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     520.1
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          2.57e-314
# Time:                        18:22:04   Log-Likelihood:                -9741.7
# No. Observations:                1386   AIC:                         1.950e+04
# Df Residuals:                    1380   BIC:                         1.953e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    708.6014     11.128     63.679      0.000     686.772     730.430
# Endcap      1159.6304     38.605     30.038      0.000    1083.899    1235.362
# Demo         470.5338     31.802     14.796      0.000     408.148     532.919
# Sales_Rep    353.3748     15.559     22.711      0.000     322.852     383.897
# Demo1_3      279.5151     20.922     13.360      0.000     238.474     320.557
# Demo4_5      303.7404     28.074     10.819      0.000     248.668     358.813
# ==============================================================================
# Omnibus:                      169.821   Durbin-Watson:                   1.367
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1223.370
# Skew:                          -0.309   Prob(JB):                    2.23e-266
# Kurtosis:                       7.561   Cond. No.                         6.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel2 = sm.OLS.from_formula('Total_Sale ~ Endcap + Sales_Rep*Demo + Demo1_3 + Demo4_5', dataModified)
goodBellyResid2 = goodBellyModel2.fit()
print(goodBellyResid2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     435.0
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          8.72e-314
# Time:                        18:22:22   Log-Likelihood:                -9739.7
# No. Observations:                1386   AIC:                         1.949e+04
# Df Residuals:                    1379   BIC:                         1.953e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        711.4272     11.207     63.480      0.000     689.442     733.412
# Endcap          1159.6544     38.564     30.071      0.000    1084.003    1235.306
# Sales_Rep        348.2490     15.757     22.102      0.000     317.339     379.159
# Demo             325.6482     79.735      4.084      0.000     169.234     482.063
# Sales_Rep:Demo   172.0598     86.849      1.981      0.048       1.689     342.430
# Demo1_3          278.8060     20.903     13.338      0.000     237.802     319.810
# Demo4_5          303.7930     28.044     10.833      0.000     248.779     358.807
# ==============================================================================
# Omnibus:                      166.541   Durbin-Watson:                   1.370
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1185.134
# Skew:                          -0.298   Prob(JB):                    4.48e-258
# Kurtosis:                       7.491   Cond. No.                         18.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel3 = sm.OLS.from_formula('Total_Sale ~ Endcap*Sales_Rep + Demo + Demo1_3 + Demo4_5', dataModified)
goodBellyResid3 = goodBellyModel3.fit()
print(goodBellyResid3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     751.9
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                        18:22:38   Log-Likelihood:                -9469.6
# No. Observations:                1386   AIC:                         1.895e+04
# Df Residuals:                    1379   BIC:                         1.899e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          740.0431      9.229     80.190      0.000     721.939     758.147
# Endcap              -9.9245     55.406     -0.179      0.858    -118.615      98.766
# Sales_Rep          294.5681     12.993     22.672      0.000     269.080     320.056
# Endcap:Sales_Rep  1736.9226     67.450     25.751      0.000    1604.607    1869.238
# Demo               453.7258     26.151     17.350      0.000     402.426     505.026
# Demo1_3            275.4104     17.199     16.013      0.000     241.671     309.150
# Demo4_5            331.7582     23.104     14.359      0.000     286.435     377.081
# ==============================================================================
# Omnibus:                       12.875   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.117
# Skew:                           0.180   Prob(JB):                     0.000860
# Kurtosis:                       3.339   Cond. No.                         16.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel4 = sm.OLS.from_formula('Total_Sale ~ Sales_Rep + Endcap*Demo + Demo1_3 + Demo4_5', dataModified)
goodBellyResid4 = goodBellyModel4.fit()
print(goodBellyResid4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     440.7
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          2.57e-316
# Time:                        18:23:19   Log-Likelihood:                -9733.9
# No. Observations:                1386   AIC:                         1.948e+04
# Df Residuals:                    1379   BIC:                         1.952e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     710.4650     11.079     64.127      0.000     688.732     732.198
# Sales_Rep     354.4057     15.479     22.895      0.000     324.040     384.771
# Endcap       1097.9103     41.444     26.491      0.000    1016.610    1179.211
# Demo          431.3404     33.147     13.013      0.000     366.317     496.363
# Endcap:Demo   433.6256    109.506      3.960      0.000     218.809     648.442
# Demo1_3       278.9135     20.812     13.402      0.000     238.087     319.740
# Demo4_5       301.2528     27.933     10.785      0.000     246.457     356.049
# ==============================================================================
# Omnibus:                      166.800   Durbin-Watson:                   1.376
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1333.815
# Skew:                          -0.235   Prob(JB):                    2.32e-290
# Kurtosis:                       7.783   Cond. No.                         18.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel5 = sm.OLS.from_formula('Total_Sale ~ Endcap*Sales_Rep*Demo + Demo1_3 + Demo4_5', dataModified)
goodBellyResid5 = goodBellyModel5.fit()
print(goodBellyResid5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     500.9
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                        18:24:01   Log-Likelihood:                -9468.9
# No. Observations:                1386   AIC:                         1.896e+04
# Df Residuals:                    1376   BIC:                         1.901e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               741.0277      9.306     79.625      0.000     722.771     759.284
# Endcap                   -1.4047     57.108     -0.025      0.980    -113.432     110.623
# Sales_Rep               293.1375     13.189     22.226      0.000     267.265     319.010
# Endcap:Sales_Rep       1718.4810     71.351     24.085      0.000    1578.512    1858.450
# Demo                    401.7344     68.502      5.865      0.000     267.355     536.114
# Endcap:Demo            -107.1822    241.934     -0.443      0.658    -581.782     367.418
# Sales_Rep:Demo           59.0991     74.736      0.791      0.429     -87.509     205.707
# Endcap:Sales_Rep:Demo   154.4302    261.621      0.590      0.555    -358.788     667.649
# Demo1_3                 274.9695     17.213     15.974      0.000     241.203     308.736
# Demo4_5                 331.2183     23.134     14.317      0.000     285.836     376.600
# ==============================================================================
# Omnibus:                       13.314   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.570
# Skew:                           0.185   Prob(JB):                     0.000686
# Kurtosis:                       3.339   Cond. No.                         69.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
goodBellyModel7 = sm.OLS.from_formula('Total_Sale ~ Endcap*Sales_Rep + Demo + Demo1_3 + Demo4_5', dataModified)
goodBellyResid7 = goodBellyModel7.fit()
print(goodBellyResid7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Total_Sale   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     564.7
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):               0.00
# Time:                        22:03:45   Log-Likelihood:                -9468.1
# No. Observations:                1386   AIC:                         1.895e+04
# Df Residuals:                    1377   BIC:                         1.900e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                732.1964     10.682     68.547      0.000     711.242     753.151
# Region == "SW"[T.True]    14.6123     27.765      0.526      0.599     -39.854      69.078
# Region == "FL"[T.True]    45.7421     27.017      1.693      0.091      -7.256      98.740
# Endcap                   -32.2976     57.169     -0.565      0.572    -144.445      79.850
# Sales_Rep                301.6506     13.878     21.737      0.000     274.427     328.874
# Endcap:Sales_Rep        1758.8663     68.858     25.543      0.000    1623.788    1893.945
# Demo                     455.3333     26.162     17.404      0.000     404.012     506.655
# Demo1_3                  277.4788     17.243     16.092      0.000     243.653     311.305
# Demo4_5                  333.1383     23.119     14.410      0.000     287.786     378.491
# ==============================================================================
# Omnibus:                       12.814   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.069
# Skew:                           0.179   Prob(JB):                     0.000881
# Kurtosis:                       3.340   Cond. No.                         17.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The best model currently I find is 3 and 5. We need to do some test on them.
